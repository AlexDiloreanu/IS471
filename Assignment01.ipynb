# %% [markdown]
# # Intro to Jupyter Notebooks

# %% [markdown]
# ### 1) Enter your name below in a markdown cell

# %% [markdown]
# Alexandru Diloreanu

# %% [markdown]
# ### 2) Using the Python 'Print' Command, print your name and Major to the
#
# ---
#
# output cell

# %%
print('Alexandru')
print('Information Systems')
# Out:
# Alexandru
# Information Systems

# %% [markdown]
# ### 3) Sum the number 65 and 24

# %%
sum = 65 + 24
print(sum)
# Out:
# 89

# %% [markdown]
# ### 4) Assign variables for your first and last name and then print the result

# %%
strFirstName = 'Alexandru'
strLastName = 'Diloreanu'
print(strFirstName, strLastName)
# Out:
# Alexandru Diloreanu

# %% [markdown]
# ### 5) On your own

# %%
x = 1
y = 1
z = 1
total = (x+y+z)
print(total)
# Out:
# 3
